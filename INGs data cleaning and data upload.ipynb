# %%
print('sss')
# Out:
# sss

# %%
len(df)
# Out:
# 4336

# %%
### step 1:- Data Extraction


## import liberaries
import pandas as pd
import numpy as np
from datetime import datetime as dt
import datetime
import pyautogui

df= pd.read_excel(r'C:\Users\arvinmvn\Desktop\cn2ww and ings\Load Job.v5 (4th Dec).xlsx',)
#df= pd.read_excel(r'W:\My Documents\cn2ww and ings\Load Job.v5 (4th Dec).xlsx',)
#df= pd.read_excel(r'C:\Users\arvinmvn\Downloads\sssoutput_INGs.xlsx',)
df.head()
print('data extract done')
# Out:
# data extract done

# %%
### step 2:- Data Cleaning

## The goal of the script is to automate the data cleaning points for INGs data analysis

##this handles the below

##convert all the dates to datetime types, and handle the column values not inlined with the format
## handle datetime value and convert to y-m-d format
##handle the spaces (trail, lead and between words, max allowable is single space)
## sellercustomerid should not be blank


## format template for reference

# <DATA CHARSET="UTF8" DELIMITER="\t">
#   <COLUMNS>
#    <COLUMN ID="sellercustomerid" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    <COLUMN ID="origin_port" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    <COLUMN ID="destination_port" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    <COLUMN ID="pickupdateinutc" DATA_TYPE="DATE" DATE_MASK="YYYY-MM-DD"/>
#    <COLUMN ID="deliverydateinutc" DATA_TYPE="DATE" DATE_MASK="YYYY-MM-DD"/>
#    <COLUMN ID="custom_clearance_date_of_origin" DATA_TYPE="DATE" DATE_MASK="YYYY-MM-DD"/>
#    <COLUMN ID="Expected_Shipping_Out_from_Origin_Date" DATA_TYPE="DATE" DATE_MASK="YYYY-MM-DD"/>
#    <COLUMN ID="Actual_Shipping_Out_from_Origin_Date" DATA_TYPE="DATE" DATE_MASK="YYYY-MM-DD"/>
#    <COLUMN ID="Expected_Shipping_To_Transit_Date" DATA_TYPE="DATE" DATE_MASK="YYYY-MM-DD"/>
#    <COLUMN ID="Actual_Shipping_To_Transit_Date" DATA_TYPE="DATE" DATE_MASK="YYYY-MM-DD"/>
#    <COLUMN ID="Expected_Shipping_From_Transit_Date" DATA_TYPE="DATE" DATE_MASK="YYYY-MM-DD"/>
#    <COLUMN ID="Actual_Shipping_From_Transit_Date" DATA_TYPE="DATE" DATE_MASK="YYYY-MM-DD"/>
#    <COLUMN ID="Expected_Shipping_To_Destination_Date" DATA_TYPE="DATE" DATE_MASK="YYYY-MM-DD"/>
#    <COLUMN ID="Actual_Shipping_To_Destination_Date" DATA_TYPE="DATE" DATE_MASK="YYYY-MM-DD"/>
#    <COLUMN ID="port_to_port_of_Reason" DATA_TYPE="VARCHAR2" DATA_LENGTH="200"/>
#    <COLUMN ID="FC_Appointment_received_Date" DATA_TYPE="DATE" DATE_MASK="YYYY-MM-DD"/>
#    <COLUMN ID="liner_details" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    <COLUMN ID="port_to_door_of_reason" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    <COLUMN ID="container_number" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    <COLUMN ID="Console_number" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    <COLUMN ID="total_shipment_kgs" DATA_TYPE="NUMBER" DATA_PRECISION="10" DATA_SCALE="3"/>
#    <COLUMN ID="total_shipment_volumn" DATA_TYPE="NUMBER" DATA_PRECISION="10" DATA_SCALE="3"/>
#    <COLUMN ID="shipment_invoice_value" DATA_TYPE="NUMBER" DATA_PRECISION="10" DATA_SCALE="3"/>
#    <COLUMN ID="shipmentid" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    <COLUMN ID="tracking_id" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    <COLUMN ID="us_coast_port" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    <COLUMN ID="type_of_shipping_mode_offered" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    <COLUMN ID="provider_id" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    <COLUMN ID="reason_for_delay_at_origin" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    <COLUMN ID="reason_for_delay_at_destination_port" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    <COLUMN ID="reason_for_delay_at_destination_fc" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    <COLUMN ID="reason_for_delay_at_transit_port" DATA_TYPE="VARCHAR2" DATA_LENGTH="100"/>
#    </COLUMNS>
# </DATA>



## sellercustomerid should not be blank, replace the NaN with Null49

df['sellercustomerid'] = df['sellercustomerid'].fillna('NULL49')


## limit the port_to_door_of_reason to 100 columns
df['port_to_door_of_reason']=df['port_to_door_of_reason'].str[0:100]

## hand double spacing between words

df=df.replace('\s+', ' ', regex=True) 



##convert all the dates to datetime types, and handle the column values not inlined with the format

df['FC_Appointment_received_Date']=pd.to_datetime(df['FC_Appointment_received_Date'], errors='coerce')


df['pickupdateinutc']=pd.to_datetime(df['pickupdateinutc'], errors='coerce')
df['deliverydateinutc']=pd.to_datetime(df['deliverydateinutc'], errors='coerce')
df['custom_clearance_date_of_origin']=pd.to_datetime(df['custom_clearance_date_of_origin'], errors='coerce')
df['Expected_Shipping_Out_from_Origin_Date']=pd.to_datetime(df['Expected_Shipping_Out_from_Origin_Date'], errors='coerce')
df['Actual_Shipping_Out_from_Origin_Date']=pd.to_datetime(df['Actual_Shipping_Out_from_Origin_Date'], errors='coerce')
df['Expected_Shipping_To_Transit_Date']=pd.to_datetime(df['Expected_Shipping_To_Transit_Date'], errors='coerce')
df['Actual_Shipping_To_Transit_Date']=pd.to_datetime(df['Actual_Shipping_To_Transit_Date'], errors='coerce')
df['Expected_Shipping_From_Transit_Date']=pd.to_datetime(df['Expected_Shipping_From_Transit_Date'], errors='coerce')
df['Actual_Shipping_From_Transit_Date']=pd.to_datetime(df['Actual_Shipping_From_Transit_Date'], errors='coerce')
df['Expected_Shipping_To_Destination_Date']=pd.to_datetime(df['Expected_Shipping_To_Destination_Date'], errors='coerce')
df['Actual_Shipping_To_Destination_Date']=pd.to_datetime(df['Actual_Shipping_To_Destination_Date'], errors='coerce')
df['FC_Appointment_received_Date']=pd.to_datetime(df['FC_Appointment_received_Date'], errors='coerce')



## handle datetime value and convert to y-m-d format

df['pickupdateinutc']=df['pickupdateinutc'].dt.strftime("%Y-%m-%d")
df['deliverydateinutc']=df['deliverydateinutc'].dt.strftime("%Y-%m-%d")
df['custom_clearance_date_of_origin']=df['custom_clearance_date_of_origin'].dt.strftime("%Y-%m-%d")
df['Expected_Shipping_Out_from_Origin_Date']=df['Expected_Shipping_Out_from_Origin_Date'].dt.strftime("%Y-%m-%d")
df['Actual_Shipping_Out_from_Origin_Date']=df['Actual_Shipping_Out_from_Origin_Date'].dt.strftime("%Y-%m-%d")
df['Expected_Shipping_To_Transit_Date']=df['Expected_Shipping_To_Transit_Date'].dt.strftime("%Y-%m-%d")
df['Actual_Shipping_To_Transit_Date']=df['Actual_Shipping_To_Transit_Date'].dt.strftime("%Y-%m-%d")
df['Expected_Shipping_From_Transit_Date']=df['Expected_Shipping_From_Transit_Date'].dt.strftime("%Y-%m-%d")
df['Actual_Shipping_From_Transit_Date']=df['Actual_Shipping_From_Transit_Date'].dt.strftime("%Y-%m-%d")
df['Expected_Shipping_To_Destination_Date']=df['Expected_Shipping_To_Destination_Date'].dt.strftime("%Y-%m-%d")
df['Actual_Shipping_To_Destination_Date']=df['Actual_Shipping_To_Destination_Date'].dt.strftime("%Y-%m-%d")
df['FC_Appointment_received_Date']=df['FC_Appointment_received_Date'].dt.strftime("%Y-%m-%d")


##handle the spaces

df['sellercustomerid']=df['sellercustomerid'].str.strip()
df['origin_port']=df['origin_port'].str.strip() 
df['destination_port']=df['destination_port'].str.strip() 
df['pickupdateinutc']=df['pickupdateinutc'].str.strip()
df['deliverydateinutc']=df['deliverydateinutc'].str.strip()
df['custom_clearance_date_of_origin']=df['custom_clearance_date_of_origin'].str.strip()
df['Expected_Shipping_Out_from_Origin_Date']=df['Expected_Shipping_Out_from_Origin_Date'].str.strip()
df['Actual_Shipping_Out_from_Origin_Date']=df['Actual_Shipping_Out_from_Origin_Date'].str.strip()
df['Expected_Shipping_To_Transit_Date']=df['Expected_Shipping_To_Transit_Date'].str.strip()
df['Actual_Shipping_To_Transit_Date']=df['Actual_Shipping_To_Transit_Date'].str.strip()
df['Expected_Shipping_From_Transit_Date']=df['Expected_Shipping_From_Transit_Date'].str.strip()
df['Actual_Shipping_From_Transit_Date']=df['Actual_Shipping_From_Transit_Date'].str.strip()
df['Expected_Shipping_To_Destination_Date']=df['Expected_Shipping_To_Destination_Date'].str.strip()
df['Actual_Shipping_To_Destination_Date']=df['Actual_Shipping_To_Destination_Date'].str.strip()
df['port_to_port_of_Reason']=df['port_to_port_of_Reason'].str.strip()
df['FC_Appointment_received_Date']=df['FC_Appointment_received_Date'].str.strip()  
df['liner_details']=df['liner_details'].str.strip()
df['port_to_door_of_reason']=df['port_to_door_of_reason'].str.strip()
df['Container #']=df['Container #'].str.strip()
df['Console #']=df['Console #'].str.strip()
df['Gross weight']=df['Gross weight'].astype(str).str.strip()
df['Gross weight']=df['Gross weight'].astype(float) # used strip to remove space in df, converted to float->str and float
df['total_shipment_volumn']=df['total_shipment_volumn'].astype(str).str.strip()
df['total_shipment_volumn']=df['total_shipment_volumn'].astype(float)
df['shipment_invoice_value']=df['shipment_invoice_value'].astype(str)
df['shipment_invoice_value']=df['shipment_invoice_value'].astype(float)
df['shipmentid']=df['shipmentid'].str.strip()
df['tracking_id']=df['tracking_id'].str.strip()  
df['us_coast_port']=df['us_coast_port'].str.strip() 
df['type_of_shipping_mode_offered']=df['type_of_shipping_mode_offered'].str.strip()
df['provider_id']=df['provider_id'].str.strip() 
df['reason_for_delay_at_origin']=df['reason_for_delay_at_origin'].str.strip()
df['reason_for_delay_at_destination_port']=df['reason_for_delay_at_destination_port'].str.strip()
df['reason_for_delay_at_destination_fc']=df['reason_for_delay_at_destination_fc'].str.strip()
df['reason_for_delay_at_transit_port']=df['reason_for_delay_at_transit_port'].str.strip()


## output txt file
df.to_excel(r'C:\Users\arvinmvn\desktop\sssoutput_INGs.xlsx',index=False)
#df.to_csv(r'C:\Users\arvinmvn\desktop\sssoutput_INGs.txt', sep='\t', index=False,header=False)

print('data cleaning done')
# Out:
# data cleaning done

# %%
### step 3:- Data Upload in EDX

from selenium.webdriver.support.ui import WebDriverWait
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.action_chains import ActionChains
import time


## file upload selenium

driver = webdriver.Firefox(executable_path=r"C:\Users\arvinmvn\Downloads\geckodriver-v0.30.0-win64\geckodriver.exe")

driver.get("https://datacentral.a2z.com/edx/providers/in-3p-bi/subjects/ates-main-data/datasets/international-shipment-fba/upload") #this will load the the google homepage.

#username='arvinmvn'
#password='Shankaram@49eneccccburvfiggfgtggndbbcfjrcfvkbegdcdvrhhfn'

## fill username
username = driver.find_element_by_xpath('//*[@id="user_name_field"]')
username.send_keys('arvinmvn')

## click on sign in

# sign_in = WebDriverWait(driver, 10).until(
#     EC.presence_of_element_located((By.XPATH, ''))).click()

driver.find_element_by_xpath('//*[@id="user_name_btn"]').click()

time.sleep(2)
## security pin

password = driver.find_element_by_xpath('//*[@id="password_field"]')
password.send_keys('Shankaram@49eneccccburvfiggfgtggndbbcfjrcfvkbegdcdvrhhfn')

## submit

driver.find_element_by_xpath('//*[@id="password_btn"]').click()

time.sleep(20)


## scroll down
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(20)

# ## enter date

last_sat = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/div/div[2]/div/div/div/section/div/div/div[2]/div/div/form/div[1]/div/input')
driver.find_element_by_xpath('/html/body/div[2]/div[2]/div/div/div[2]/div/div/div/section/div/div/div[2]/div/div/form/div[1]/div/input').clear()
time.sleep(2)
last_sat.send_keys('2022-02-13')

## click next

driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div/div[2]/div/div/div/section/div/div/div[2]/div/div/form/div[2]/button").click()
time.sleep(5)

## upload xml schema

driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div/div[2]/div/div/div/section/div/form/label").click()

pyautogui.write(r'C:\Users\arvinmvn\Desktop\intl_shp_schema.txt',interval=0.25) 
pyautogui.press('return')

time.sleep(10)




# upload file

driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div/div[2]/div/div/div/section/div/div/form/label").click()

pyautogui.write(r'C:\Users\arvinmvn\Desktop\sssoutput_INGs.txt',interval=0.25) 
pyautogui.press('return')

time.sleep(15)
## click on encrypt and upload

driver.find_element_by_xpath("/html/body/div[2]/div[2]/div/div/div[2]/div/div/div/section/div/button").click()

print('data upload done')
# Out:
# <ipython-input-5-0c1c0ee66ba4>:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path=r"C:\Users\arvinmvn\Downloads\geckodriver-v0.30.0-win64\geckodriver.exe")
# <ipython-input-5-0c1c0ee66ba4>:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   username = driver.find_element_by_xpath('//*[@id="user_name_field"]')
# <ipython-input-5-0c1c0ee66ba4>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="user_name_btn"]').click()
# <ipython-input-5-0c1c0ee66ba4>:33: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   password = driver.find_element_by_xpath('//*[@id="password_field"]')
# <ipython-input-5-0c1c0ee66ba4>:38: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
### step 4:- Check Job run history

## job link


driver2 = webdriver.Firefox(executable_path=r"C:\Users\arvinmvn\Downloads\geckodriver-v0.30.0-win64\geckodriver.exe")
driver2.get("https://datacentral.a2z.com/dw-platform/servlet/dwp/template/DWPJobPerformanceHistory.vm/job_id/20769481") #this will load the the google homepage.

## fill username
username = driver2.find_element_by_xpath('//*[@id="user_name_field"]')
username.send_keys('arvinmvn')

## click on sign in

# sign_in = WebDriverWait(driver, 10).until(
#     EC.presence_of_element_located((By.XPATH, ''))).click()

driver2.find_element_by_xpath('//*[@id="user_name_btn"]').click()

time.sleep(2)
## security pin

password = driver2.find_element_by_xpath('//*[@id="password_field"]')
password.send_keys('Shankaram@49eneccccburvfiggfgtggndbbcfjrcfvkbegdcdvrhhfn')

## submit

driver2.find_element_by_xpath('//*[@id="password_btn"]').click()

time.sleep(20)               


print('job history opened')
# Out:
# <ipython-input-4-1114f4c85d7b>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver2 = webdriver.Firefox(executable_path=r"C:\Users\arvinmvn\Downloads\geckodriver-v0.30.0-win64\geckodriver.exe")
# <ipython-input-4-1114f4c85d7b>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   username = driver2.find_element_by_xpath('//*[@id="user_name_field"]')
# <ipython-input-4-1114f4c85d7b>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver2.find_element_by_xpath('//*[@id="user_name_btn"]').click()
# <ipython-input-4-1114f4c85d7b>:21: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   password = driver2.find_element_by_xpath('//*[@id="password_field"]')
# ...
